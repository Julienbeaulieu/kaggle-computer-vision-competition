# %%
from src.visualization.visualize import visual_check_bengali
# Make sure to set the .env PATH_DATA_INTERIM to the interim path containing the processed data 
visual_check_bengali()
# Out:
# 2.3054556846618652
